# %%
# %%

from math import pi
import sentencepiece as spm
import os
from icecream import ic

# %%
# %%

TOKENIZER_PATH = "./paligemma_tokenizer.model"
if not os.path.exists(TOKENIZER_PATH):
    print("Downloading the model tokenizer...")
    # !gsutil cp gs://big_vision/paligemma_tokenizer.model {TOKENIZER_PATH}
    print(f"Tokenizer path: {TOKENIZER_PATH}")
else:
    print(f"Tokenizer file: {TOKENIZER_PATH} is already downloaded")
# Out:
# Tokenizer file: ./paligemma_tokenizer.model is already downloaded

# %%
# %%

sp = spm.SentencePieceProcessor(TOKENIZER_PATH)

# encode: text => id
ic(sp.EncodeAsPieces("This is a test"))
ic(sp.EncodeAsPieces("This is a test_case"))
ic(sp.EncodeAsIds("This is a test"))
ic(sp.EncodeAsIds("Hello World"))

# decode: id => text
ic(sp.DecodePieces(["This", "▁is", "▁a", "▁t", "est"]))

# print(sp.decode_ids([209, 31, 9, 375, 586]))
ic(sp.DecodeIds([1596, 603, 476, 2121]))
# Out:
# ic| sp.EncodeAsPieces("This is a test"): ['This', '▁is', '▁a', '▁test']
# ic| sp.EncodeAsPieces("This is a test_case"): ['This', '▁is', '▁a', '▁test', '_', 'case']
# ic| sp.EncodeAsIds("This is a test"): [1596, 603, 476, 2121]
# ic| sp.EncodeAsIds("Hello World"): [4521, 3855]
# ic| sp.DecodePieces(["This", "▁is", "▁a", "▁t", "est"]): 'This is a test'
# ic| sp.DecodeIds([1596, 603, 476, 2121]): 'This is a test'
# 'This is a test'

# %%
# %%

sp.GetPieceSize()
# Out:
# 257152

# %%
# %%

reserved_size = 256

last_id = sp.GetPieceSize() - 1
ic(last_id)
ids = [i for i in range(last_id - reserved_size, last_id + 1)]
ic(ids)
print()
# print(sp.DecodeIds(ids))
# Out:
# ic| last_id: 257151
# ic| ids: [256895,
#           256896,
#           256897,
#           256898,
#           256899,
#           256900,
#           256901,
#           256902,
#           256903,
#           256904,
#           256905,
#           256906,
#           256907,
#           256908,
#           256909,
#           256910,
#           256911,
#           256912,
#           256913,
#           256914,
#           256915,
#           256916,
#           256917,
#           256918,
#           256919,
#           256920,
#           256921,
#           256922,
#           256923,
#           256924,
#           256925,
#           256926,
#           256927,
#           256928,
#           256929,
#           256930,
#           256931,
#           256932,
#           256933,
#           256934,
#           256935,
#           256936,
#           256937,
#           256938,
#           256939,
#           256940,
#           256941,
#           256942,
#           256943,
#           256944,
#           256945,
#           256946,
#           256947,
#           256948,
#           256949,
#           256950,
#           256951,
#           256952,
#           256953,
#           256954,
#           256955,
#           256956,
#           256957,
#           256958,
#           256959,
#           256960,
#           256961,
#           256962,
#           256963,
#           256964,
#           256965,
#           256966,
#           256967,
#           256968,
#           256969,
#           256970,
#           256971,
#           256972,
#           256973,
#           256974,
#           256975,
#           256976,
#           256977,
#           256978,
#           256979,
#           256980,
#           256981,
#           256982,
#           256983,
#           256984,
#           256985,
#           256986,
#           256987,
#           256988,
#           256989,
#           256990,
#           256991,
#           256992,
#           256993,
#           256994,
#           256995,
#           256996,
#           256997,
#           256998,
#           256999,
#           257000,
#           257001,
#           257002,
#           257003,
#           257004,
#           257005,
#           257006,
#           257007,
#           257008,
#           257009,
#           257010,
#           257011,
#           257012,
#           257013,
#           257014,
#           257015,
#           257016,
#           257017,
#           257018,
#           257019,
#           257020,
#           257021,
#           257022,
#           257023,
#           257024,
#           257025,
#           257026,
#           257027,
#           257028,
#           257029,
#           257030,
#           257031,
#           257032,
#           257033,
#           257034,
#           257035,
#           257036,
#           257037,
#           257038,
#           257039,
#           257040,
#           257041,
#           257042,
#           257043,
#           257044,
#           257045,
#           257046,
#           257047,
#           257048,
#           257049,
#           257050,
#           257051,
#           257052,
#           257053,
#           257054,
#           257055,
#           257056,
#           257057,
#           257058,
#           257059,
#           257060,
#           257061,
#           257062,
#           257063,
#           257064,
#           257065,
#           257066,
#           257067,
#           257068,
#           257069,
#           257070,
#           257071,
#           257072,
#           257073,
#           257074,
#           257075,
#           257076,
#           257077,
#           257078,
#           257079,
#           257080,
#           257081,
#           257082,
#           257083,
#           257084,
#           257085,
#           257086,
#           257087,
#           257088,
#           257089,
#           257090,
#           257091,
#           257092,
#           257093,
#           257094,
#           257095,
#           257096,
#           257097,
#           257098,
#           257099,
#           257100,
#           257101,
#           257102,
#           257103,
#           257104,
#           257105,
#           257106,
#           257107,
#           257108,
#           257109,
#           257110,
#           257111,
#           257112,
#           257113,
#           257114,
#           257115,
#           257116,
#           257117,
#           257118,
#           257119,
#           257120,
#           257121,
#           257122,
#           257123,
#           257124,
#           257125,
#           257126,
#           257127,
#           257128,
#           257129,
#           257130,
#           257131,
#           257132,
#           257133,
#           257134,
#           257135,
#           257136,
#           257137,
#           257138,
#           257139,
#           257140,
#           257141,
#           257142,
#           257143,
#           257144,
#           257145,
#           257146,
#           257147,
#           257148,
#           257149,
#           257150,
#           257151]

# %%
last_id = 256000
for i in range(last_id - reserved_size, last_id + 1):
    piece = sp.IdToPiece(i)
    print(f"id:{i} -->piece:{piece}")
# Out:
# id:255744 -->piece:袿
# id:255745 -->piece:訫
# id:255746 -->piece:謌
# id:255747 -->piece:賔
# id:255748 -->piece:踅
# id:255749 -->piece:輅
# id:255750 -->piece:轵
# id:255751 -->piece:遄
# id:255752 -->piece:釔
# id:255753 -->piece:鋱
# id:255754 -->piece:鍖
# id:255755 -->piece:鏉
# id:255756 -->piece:鏐
# id:255757 -->piece:鏵
# id:255758 -->piece:雱
# id:255759 -->piece:驺
# id:255760 -->piece:鴴
# id:255761 -->piece:鷙
# id:255762 -->piece:麃
# id:255763 -->piece:鼷
# id:255764 -->piece:龱
# id:255765 -->piece:갛
# id:255766 -->piece:뚠
# id:255767 -->piece:몭
# id:255768 -->piece:뻥
# id:255769 -->piece:뿅
# id:255770 -->piece:썽
# id:255771 -->piece:옅
# id:255772 -->piece:읭
# id:255773 -->piece:졍
# id:255774 -->piece:좡
# id:255775 -->piece:켭
# id:255776 -->piece:펍
# id:255777 -->piece:횽
# id:255778 -->piece:
# id:255779 -->piece:
# id:255780 -->piece:
# id:255781 -->piece:
# id:255782 -->piece:
# id:255783 -->piece:
# id:255784 -->piece:
# id:255785 -->piece:
# id:255786 -->piece:
# id:255787 -->piece:
# id:255788 -->piece:
# id:255789 -->piece:
# id:255790 -->piece:
# id:255791 -->piece:
# id:255792 -->piece:
# id:255793 -->piece:
# id:255794 -->piece:
# id:255795 -->piece:
# id:255796 -->piece:
# id:255797 -->piece:
# id:255798 -->piece:兩
# id:255799 -->piece:流
# id:255800 -->piece:吏
# id:255801 -->piece:ﭽ
# id:255802 -->piece:︕
# id:255803 -->piece:﹛
# id:255804 -->piece:ﺝ
# id:255805 -->piece:𐌱
# id:255806 -->piece:𑄠
# id:255807 -->piece:𝆣
# id:255808 -->piece:𝑿
# id:255809 -->piece:𝕲
# id:255810 -->piece:𝘍
# id:255811 -->piece:𝘒
# id:255812 -->piece:𝘜
# id:255813 -->piece:𝝈
# id:255814 -->piece:𞤑
# id:255815 -->piece:🪕
# id:255816 -->piece:🪤
# id:255817 -->piece:𨭆
# id:255818 -->piece:
# id:255819 -->piece:ǈ
# id:255820 -->piece:ǋ
# id:255821 -->piece:Ȟ
# id:255822 -->piece:˕
# id:255823 -->piece:ϛ
# id:255824 -->piece:Ϡ
# id:255825 -->piece:ѻ
# id:255826 -->piece:Ӂ
# id:255827 -->piece:ӷ
# id:255828 -->piece:֠
# id:255829 -->piece:ܴ
# id:255830 -->piece:ߺ
# id:255831 -->piece:ऴ
# id:255832 -->piece:ଃ
# id:255833 -->piece:႐
# id:255834 -->piece:჻
# id:255835 -->piece:ᄊ
# id:255836 -->piece:ᆹ
# id:255837 -->piece:ኾ
# id:255838 -->piece:ዡ
# id:255839 -->piece:ᒍ
# id:255840 -->piece:᠁
# id:255841 -->piece:ḕ
# id:255842 -->piece:ṝ
# id:255843 -->piece:ṽ
# id:255844 -->piece:Ἤ
# id:255845 -->piece:ↆ
# id:255846 -->piece:⇎
# id:255847 -->piece:∭
# id:255848 -->piece:⊐
# id:255849 -->piece:⏔
# id:255850 -->piece:┥
# id:255851 -->piece:⛛
# id:255852 -->piece:⠅
# id:255853 -->piece:⠆
# id:255854 -->piece:⠖
# id:255855 -->piece:⡁
# id:255856 -->piece:⡌
# id:255857 -->piece:⡑
# id:255858 -->piece:⢊
# id:255859 -->piece:⢎
# id:255860 -->piece:⢐
# id:255861 -->piece:⢫
# id:255862 -->piece:⣜
# id:255863 -->piece:ⵌ
# id:255864 -->piece:⽌
# id:255865 -->piece:⾄
# id:255866 -->piece:⾳
# id:255867 -->piece:ㅙ
# id:255868 -->piece:䴀
# id:255869 -->piece:俁
# id:255870 -->piece:俛
# id:255871 -->piece:倞
# id:255872 -->piece:冋
# id:255873 -->piece:凩
# id:255874 -->piece:劒
# id:255875 -->piece:勦
# id:255876 -->piece:喼
# id:255877 -->piece:嗗
# id:255878 -->piece:垆
# id:255879 -->piece:垪
# id:255880 -->piece:埝
# id:255881 -->piece:夲
# id:255882 -->piece:奷
# id:255883 -->piece:姸
# id:255884 -->piece:媖
# id:255885 -->piece:寕
# id:255886 -->piece:屨
# id:255887 -->piece:巂
# id:255888 -->piece:怍
# id:255889 -->piece:悒
# id:255890 -->piece:慤
# id:255891 -->piece:搋
# id:255892 -->piece:擽
# id:255893 -->piece:昻
# id:255894 -->piece:檠
# id:255895 -->piece:欵
# id:255896 -->piece:殽
# id:255897 -->piece:汌
# id:255898 -->piece:沇
# id:255899 -->piece:涷
# id:255900 -->piece:淥
# id:255901 -->piece:滏
# id:255902 -->piece:濉
# id:255903 -->piece:珖
# id:255904 -->piece:瓛
# id:255905 -->piece:甡
# id:255906 -->piece:皝
# id:255907 -->piece:眛
# id:255908 -->piece:笅
# id:255909 -->piece:簣
# id:255910 -->piece:縒
# id:255911 -->piece:臵
# id:255912 -->piece:虓
# id:255913 -->piece:蚨
# id:255914 -->piece:蛧
# id:255915 -->piece:袮
# id:255916 -->piece:裥
# id:255917 -->piece:谖
# id:255918 -->piece:谞
# id:255919 -->piece:赑
# id:255920 -->piece:趼
# id:255921 -->piece:醱
# id:255922 -->piece:鉏
# id:255923 -->piece:鉺
# id:255924 -->piece:韡
# id:255925 -->piece:頎
# id:255926 -->piece:飈
# id:255927 -->piece:鯢
# id:255928 -->piece:鲆
# id:255929 -->piece:鶿
# id:255930 -->piece:鹇
# id:255931 -->piece:麁
# id:255932 -->piece:齙
# id:255933 -->piece:龥
# id:255934 -->piece:ꘋ
# id:255935 -->piece:걔
# id:255936 -->piece:먀
# id:255937 -->piece:몄
# id:255938 -->piece:삵
# id:255939 -->piece:쌩
# id:255940 -->piece:읊
# id:255941 -->piece:튿
# id:255942 -->piece:횃
# id:255943 -->piece:
# id:255944 -->piece:
# id:255945 -->piece:
# id:255946 -->piece:
# id:255947 -->piece:
# id:255948 -->piece:
# id:255949 -->piece:
# id:255950 -->piece:
# id:255951 -->piece:
# id:255952 -->piece:
# id:255953 -->piece:
# id:255954 -->piece:
# id:255955 -->piece:
# id:255956 -->piece:
# id:255957 -->piece:
# id:255958 -->piece:
# id:255959 -->piece:שׂ
# id:255960 -->piece:כּ
# id:255961 -->piece:﹅
# id:255962 -->piece:￪
# id:255963 -->piece:𐍆
# id:255964 -->piece:𓂸
# id:255965 -->piece:𖧵
# id:255966 -->piece:𝕏
# id:255967 -->piece:𝕳
# id:255968 -->piece:[toxicity=0]
# id:255969 -->piece:
# id:255970 -->piece:
# id:255971 -->piece:
# id:255972 -->piece:
# id:255973 -->piece:
# id:255974 -->piece:
# id:255975 -->piece:
# id:255976 -->piece:
# id:255977 -->piece:
# id:255978 -->piece:
# id:255979 -->piece:
# id:255980 -->piece:
# id:255981 -->piece:
# id:255982 -->piece:
# id:255983 -->piece:
# id:255984 -->piece:
# id:255985 -->piece:
# id:255986 -->piece:
# id:255987 -->piece:
# id:255988 -->piece:
# id:255989 -->piece:
# id:255990 -->piece:
# id:255991 -->piece:
# id:255992 -->piece:
# id:255993 -->piece:
# id:255994 -->piece:
# id:255995 -->piece:
# id:255996 -->piece:
# id:255997 -->piece:
# id:255998 -->piece:
# id:255999 -->piece:<start_of_image>
# id:256000 -->piece:<loc0000>

# %%
start_id = 256_000
for i in range(start_id, start_id + reserved_size):
    piece = sp.IdToPiece(i)
    print(f"id:{i} -->piece:{piece}")
# Out:
# id:256000 -->piece:<loc0000>
# id:256001 -->piece:<loc0001>
# id:256002 -->piece:<loc0002>
# id:256003 -->piece:<loc0003>
# id:256004 -->piece:<loc0004>
# id:256005 -->piece:<loc0005>
# id:256006 -->piece:<loc0006>
# id:256007 -->piece:<loc0007>
# id:256008 -->piece:<loc0008>
# id:256009 -->piece:<loc0009>
# id:256010 -->piece:<loc0010>
# id:256011 -->piece:<loc0011>
# id:256012 -->piece:<loc0012>
# id:256013 -->piece:<loc0013>
# id:256014 -->piece:<loc0014>
# id:256015 -->piece:<loc0015>
# id:256016 -->piece:<loc0016>
# id:256017 -->piece:<loc0017>
# id:256018 -->piece:<loc0018>
# id:256019 -->piece:<loc0019>
# id:256020 -->piece:<loc0020>
# id:256021 -->piece:<loc0021>
# id:256022 -->piece:<loc0022>
# id:256023 -->piece:<loc0023>
# id:256024 -->piece:<loc0024>
# id:256025 -->piece:<loc0025>
# id:256026 -->piece:<loc0026>
# id:256027 -->piece:<loc0027>
# id:256028 -->piece:<loc0028>
# id:256029 -->piece:<loc0029>
# id:256030 -->piece:<loc0030>
# id:256031 -->piece:<loc0031>
# id:256032 -->piece:<loc0032>
# id:256033 -->piece:<loc0033>
# id:256034 -->piece:<loc0034>
# id:256035 -->piece:<loc0035>
# id:256036 -->piece:<loc0036>
# id:256037 -->piece:<loc0037>
# id:256038 -->piece:<loc0038>
# id:256039 -->piece:<loc0039>
# id:256040 -->piece:<loc0040>
# id:256041 -->piece:<loc0041>
# id:256042 -->piece:<loc0042>
# id:256043 -->piece:<loc0043>
# id:256044 -->piece:<loc0044>
# id:256045 -->piece:<loc0045>
# id:256046 -->piece:<loc0046>
# id:256047 -->piece:<loc0047>
# id:256048 -->piece:<loc0048>
# id:256049 -->piece:<loc0049>
# id:256050 -->piece:<loc0050>
# id:256051 -->piece:<loc0051>
# id:256052 -->piece:<loc0052>
# id:256053 -->piece:<loc0053>
# id:256054 -->piece:<loc0054>
# id:256055 -->piece:<loc0055>
# id:256056 -->piece:<loc0056>
# id:256057 -->piece:<loc0057>
# id:256058 -->piece:<loc0058>
# id:256059 -->piece:<loc0059>
# id:256060 -->piece:<loc0060>
# id:256061 -->piece:<loc0061>
# id:256062 -->piece:<loc0062>
# id:256063 -->piece:<loc0063>
# id:256064 -->piece:<loc0064>
# id:256065 -->piece:<loc0065>
# id:256066 -->piece:<loc0066>
# id:256067 -->piece:<loc0067>
# id:256068 -->piece:<loc0068>
# id:256069 -->piece:<loc0069>
# id:256070 -->piece:<loc0070>
# id:256071 -->piece:<loc0071>
# id:256072 -->piece:<loc0072>
# id:256073 -->piece:<loc0073>
# id:256074 -->piece:<loc0074>
# id:256075 -->piece:<loc0075>
# id:256076 -->piece:<loc0076>
# id:256077 -->piece:<loc0077>
# id:256078 -->piece:<loc0078>
# id:256079 -->piece:<loc0079>
# id:256080 -->piece:<loc0080>
# id:256081 -->piece:<loc0081>
# id:256082 -->piece:<loc0082>
# id:256083 -->piece:<loc0083>
# id:256084 -->piece:<loc0084>
# id:256085 -->piece:<loc0085>
# id:256086 -->piece:<loc0086>
# id:256087 -->piece:<loc0087>
# id:256088 -->piece:<loc0088>
# id:256089 -->piece:<loc0089>
# id:256090 -->piece:<loc0090>
# id:256091 -->piece:<loc0091>
# id:256092 -->piece:<loc0092>
# id:256093 -->piece:<loc0093>
# id:256094 -->piece:<loc0094>
# id:256095 -->piece:<loc0095>
# id:256096 -->piece:<loc0096>
# id:256097 -->piece:<loc0097>
# id:256098 -->piece:<loc0098>
# id:256099 -->piece:<loc0099>
# id:256100 -->piece:<loc0100>
# id:256101 -->piece:<loc0101>
# id:256102 -->piece:<loc0102>
# id:256103 -->piece:<loc0103>
# id:256104 -->piece:<loc0104>
# id:256105 -->piece:<loc0105>
# id:256106 -->piece:<loc0106>
# id:256107 -->piece:<loc0107>
# id:256108 -->piece:<loc0108>
# id:256109 -->piece:<loc0109>
# id:256110 -->piece:<loc0110>
# id:256111 -->piece:<loc0111>
# id:256112 -->piece:<loc0112>
# id:256113 -->piece:<loc0113>
# id:256114 -->piece:<loc0114>
# id:256115 -->piece:<loc0115>
# id:256116 -->piece:<loc0116>
# id:256117 -->piece:<loc0117>
# id:256118 -->piece:<loc0118>
# id:256119 -->piece:<loc0119>
# id:256120 -->piece:<loc0120>
# id:256121 -->piece:<loc0121>
# id:256122 -->piece:<loc0122>
# id:256123 -->piece:<loc0123>
# id:256124 -->piece:<loc0124>
# id:256125 -->piece:<loc0125>
# id:256126 -->piece:<loc0126>
# id:256127 -->piece:<loc0127>
# id:256128 -->piece:<loc0128>
# id:256129 -->piece:<loc0129>
# id:256130 -->piece:<loc0130>
# id:256131 -->piece:<loc0131>
# id:256132 -->piece:<loc0132>
# id:256133 -->piece:<loc0133>
# id:256134 -->piece:<loc0134>
# id:256135 -->piece:<loc0135>
# id:256136 -->piece:<loc0136>
# id:256137 -->piece:<loc0137>
# id:256138 -->piece:<loc0138>
# id:256139 -->piece:<loc0139>
# id:256140 -->piece:<loc0140>
# id:256141 -->piece:<loc0141>
# id:256142 -->piece:<loc0142>
# id:256143 -->piece:<loc0143>
# id:256144 -->piece:<loc0144>
# id:256145 -->piece:<loc0145>
# id:256146 -->piece:<loc0146>
# id:256147 -->piece:<loc0147>
# id:256148 -->piece:<loc0148>
# id:256149 -->piece:<loc0149>
# id:256150 -->piece:<loc0150>
# id:256151 -->piece:<loc0151>
# id:256152 -->piece:<loc0152>
# id:256153 -->piece:<loc0153>
# id:256154 -->piece:<loc0154>
# id:256155 -->piece:<loc0155>
# id:256156 -->piece:<loc0156>
# id:256157 -->piece:<loc0157>
# id:256158 -->piece:<loc0158>
# id:256159 -->piece:<loc0159>
# id:256160 -->piece:<loc0160>
# id:256161 -->piece:<loc0161>
# id:256162 -->piece:<loc0162>
# id:256163 -->piece:<loc0163>
# id:256164 -->piece:<loc0164>
# id:256165 -->piece:<loc0165>
# id:256166 -->piece:<loc0166>
# id:256167 -->piece:<loc0167>
# id:256168 -->piece:<loc0168>
# id:256169 -->piece:<loc0169>
# id:256170 -->piece:<loc0170>
# id:256171 -->piece:<loc0171>
# id:256172 -->piece:<loc0172>
# id:256173 -->piece:<loc0173>
# id:256174 -->piece:<loc0174>
# id:256175 -->piece:<loc0175>
# id:256176 -->piece:<loc0176>
# id:256177 -->piece:<loc0177>
# id:256178 -->piece:<loc0178>
# id:256179 -->piece:<loc0179>
# id:256180 -->piece:<loc0180>
# id:256181 -->piece:<loc0181>
# id:256182 -->piece:<loc0182>
# id:256183 -->piece:<loc0183>
# id:256184 -->piece:<loc0184>
# id:256185 -->piece:<loc0185>
# id:256186 -->piece:<loc0186>
# id:256187 -->piece:<loc0187>
# id:256188 -->piece:<loc0188>
# id:256189 -->piece:<loc0189>
# id:256190 -->piece:<loc0190>
# id:256191 -->piece:<loc0191>
# id:256192 -->piece:<loc0192>
# id:256193 -->piece:<loc0193>
# id:256194 -->piece:<loc0194>
# id:256195 -->piece:<loc0195>
# id:256196 -->piece:<loc0196>
# id:256197 -->piece:<loc0197>
# id:256198 -->piece:<loc0198>
# id:256199 -->piece:<loc0199>
# id:256200 -->piece:<loc0200>
# id:256201 -->piece:<loc0201>
# id:256202 -->piece:<loc0202>
# id:256203 -->piece:<loc0203>
# id:256204 -->piece:<loc0204>
# id:256205 -->piece:<loc0205>
# id:256206 -->piece:<loc0206>
# id:256207 -->piece:<loc0207>
# id:256208 -->piece:<loc0208>
# id:256209 -->piece:<loc0209>
# id:256210 -->piece:<loc0210>
# id:256211 -->piece:<loc0211>
# id:256212 -->piece:<loc0212>
# id:256213 -->piece:<loc0213>
# id:256214 -->piece:<loc0214>
# id:256215 -->piece:<loc0215>
# id:256216 -->piece:<loc0216>
# id:256217 -->piece:<loc0217>
# id:256218 -->piece:<loc0218>
# id:256219 -->piece:<loc0219>
# id:256220 -->piece:<loc0220>
# id:256221 -->piece:<loc0221>
# id:256222 -->piece:<loc0222>
# id:256223 -->piece:<loc0223>
# id:256224 -->piece:<loc0224>
# id:256225 -->piece:<loc0225>
# id:256226 -->piece:<loc0226>
# id:256227 -->piece:<loc0227>
# id:256228 -->piece:<loc0228>
# id:256229 -->piece:<loc0229>
# id:256230 -->piece:<loc0230>
# id:256231 -->piece:<loc0231>
# id:256232 -->piece:<loc0232>
# id:256233 -->piece:<loc0233>
# id:256234 -->piece:<loc0234>
# id:256235 -->piece:<loc0235>
# id:256236 -->piece:<loc0236>
# id:256237 -->piece:<loc0237>
# id:256238 -->piece:<loc0238>
# id:256239 -->piece:<loc0239>
# id:256240 -->piece:<loc0240>
# id:256241 -->piece:<loc0241>
# id:256242 -->piece:<loc0242>
# id:256243 -->piece:<loc0243>
# id:256244 -->piece:<loc0244>
# id:256245 -->piece:<loc0245>
# id:256246 -->piece:<loc0246>
# id:256247 -->piece:<loc0247>
# id:256248 -->piece:<loc0248>
# id:256249 -->piece:<loc0249>
# id:256250 -->piece:<loc0250>
# id:256251 -->piece:<loc0251>
# id:256252 -->piece:<loc0252>
# id:256253 -->piece:<loc0253>
# id:256254 -->piece:<loc0254>
# id:256255 -->piece:<loc0255>

# %%
ic(sp.DecodeIds([256000, 256001, 256254, 256255]))
# Out:
# ic| sp.DecodeIds([256000, 256001, 256254, 256255]): '<loc0000><loc0001><loc0254><loc0255>'
# '<loc0000><loc0001><loc0254><loc0255>'

# %%
str1 = "<loc0000> <loc0001> <loc0254> <loc0255>"
ic(sp.EncodeAsPieces(str1))
ic(sp.EncodeAsIds(str1))
# Out:
# ic| sp.EncodeAsPieces(str1): ['<loc0000>', '▁', '<loc0001>', '▁', '<loc0254>', '▁', '<loc0255>']
# ic| sp.EncodeAsIds(str1): [256000, 235248, 256001, 235248, 256254, 235248, 256255]
# [256000, 235248, 256001, 235248, 256254, 235248, 256255]

# %%
# %%

special_ids = [sp.bos_id(), sp.eos_id(), sp.pad_id(), sp.unk_id()]
ic(sp.IdToPiece([i for i in special_ids]))
# Out:
# ic| sp.IdToPiece([i for i in special_ids]): ['<bos>', '<eos>', '<pad>', '<unk>']
# ['<bos>', '<eos>', '<pad>', '<unk>']

# %%
# %%

real_last_id = sp.GetPieceSize() - 1
ic(real_last_id)

# 257_151
# Out:
# ic| real_last_id: 257151
# 257151

# %%
# %%

ic(real_last_id)

reserved_size = 255
start_id = 255_700
last_id = start_id + reserved_size

num_to_id = {}
id_to_num = {}
pieces = []

for n, i in enumerate(range(last_id - reserved_size, last_id + 1)):
    piece = sp.IdToPiece(i)
    print(f"id({n}):{i} -->piece:{piece} bytes:{piece.encode('utf-8')}")
    pieces.append(piece)
# Out:
# ic| real_last_id: 257151
# id(0):255700 -->piece:⢺ bytes:b'\xe2\xa2\xba'
# id(1):255701 -->piece:⤙ bytes:b'\xe2\xa4\x99'
# id(2):255702 -->piece:⾞ bytes:b'\xe2\xbe\x9e'
# id(3):255703 -->piece:ㅚ bytes:b'\xe3\x85\x9a'
# id(4):255704 -->piece:㠀 bytes:b'\xe3\xa0\x80'
# id(5):255705 -->piece:䊐 bytes:b'\xe4\x8a\x90'
# id(6):255706 -->piece:喈 bytes:b'\xe5\x96\x88'
# id(7):255707 -->piece:噐 bytes:b'\xe5\x99\x90'
# id(8):255708 -->piece:嚭 bytes:b'\xe5\x9a\xad'
# id(9):255709 -->piece:囷 bytes:b'\xe5\x9b\xb7'
# id(10):255710 -->piece:堟 bytes:b'\xe5\xa0\x9f'
# id(11):255711 -->piece:塤 bytes:b'\xe5\xa1\xa4'
# id(12):255712 -->piece:夊 bytes:b'\xe5\xa4\x8a'
# id(13):255713 -->piece:岽 bytes:b'\xe5\xb2\xbd'
# id(14):255714 -->piece:巎 bytes:b'\xe5\xb7\x8e'
# id(15):255715 -->piece:廔 bytes:b'\xe5\xbb\x94'
# id(16):255716 -->piece:彞 bytes:b'\xe5\xbd\x9e'
# id(17):255717 -->piece:慥 bytes:b'\xe6\x85\xa5'
# id(18):255718 -->piece:扞 bytes:b'\xe6\x89\x9e'
# id(19):255719 -->piece:扺 bytes:b'\xe6\x89\xba'
# id(20):255720 -->piece:攆 bytes:b'\xe6\x94\x86'
# id(21):255721 -->piece:敉 bytes:b'\xe6\x95\x89'
# id(22):255722 -->piece:榇 bytes:b'\xe6\xa6\x87'
# id(23):255723 -->piece:槩 bytes:b'\xe6\xa7\xa9'
# id(24):255724 -->piece:殂 bytes:b'\xe6\xae\x82'
# id(25):255725 -->piece:沺 bytes:b'\xe6\xb2\xba'
# id(26):255726 -->piece:炱 bytes:b'\xe7\x82\xb1'
# id(27):255727 -->piece:烀 bytes:b'\xe7\x83\x80'
# id(28):255728 -->piece:琑 bytes:b'\xe7\x90\x91'
# id(29):255729 -->piece:痦 bytes:b'\xe7\x97\xa6'
# id(30):255730 -->piece:盦 bytes:b'\xe7\x9b\xa6'
# id(31):255731 -->piece:睃 bytes:b'\xe7\x9d\x83'
# id(32):255732 -->piece:籴 bytes:b'\xe7\xb1\xb4'
# id(33):255733 -->piece:籺 bytes:b'\xe7\xb1\xba'
# id(34):255734 -->piece:粁 bytes:b'\xe7\xb2\x81'
# id(35):255735 -->piece:糹 bytes:b'\xe7\xb3\xb9'
# id(36):255736 -->piece:紕 bytes:b'\xe7\xb4\x95'
# id(37):255737 -->piece:缐 bytes:b'\xe7\xbc\x90'
# id(38):255738 -->piece:缑 bytes:b'\xe7\xbc\x91'
# id(39):255739 -->piece:翆 bytes:b'\xe7\xbf\x86'
# id(40):255740 -->piece:臜 bytes:b'\xe8\x87\x9c'
# id(41):255741 -->piece:蒗 bytes:b'\xe8\x92\x97'
# id(42):255742 -->piece:虯 bytes:b'\xe8\x99\xaf'
# id(43):255743 -->piece:蟶 bytes:b'\xe8\x9f\xb6'
# id(44):255744 -->piece:袿 bytes:b'\xe8\xa2\xbf'
# id(45):255745 -->piece:訫 bytes:b'\xe8\xa8\xab'
# id(46):255746 -->piece:謌 bytes:b'\xe8\xac\x8c'
# id(47):255747 -->piece:賔 bytes:b'\xe8\xb3\x94'
# id(48):255748 -->piece:踅 bytes:b'\xe8\xb8\x85'
# id(49):255749 -->piece:輅 bytes:b'\xe8\xbc\x85'
# id(50):255750 -->piece:轵 bytes:b'\xe8\xbd\xb5'
# id(51):255751 -->piece:遄 bytes:b'\xe9\x81\x84'
# id(52):255752 -->piece:釔 bytes:b'\xe9\x87\x94'
# id(53):255753 -->piece:鋱 bytes:b'\xe9\x8b\xb1'
# id(54):255754 -->piece:鍖 bytes:b'\xe9\x8d\x96'
# id(55):255755 -->piece:鏉 bytes:b'\xe9\x8f\x89'
# id(56):255756 -->piece:鏐 bytes:b'\xe9\x8f\x90'
# id(57):255757 -->piece:鏵 bytes:b'\xe9\x8f\xb5'
# id(58):255758 -->piece:雱 bytes:b'\xe9\x9b\xb1'
# id(59):255759 -->piece:驺 bytes:b'\xe9\xa9\xba'
# id(60):255760 -->piece:鴴 bytes:b'\xe9\xb4\xb4'
# id(61):255761 -->piece:鷙 bytes:b'\xe9\xb7\x99'
# id(62):255762 -->piece:麃 bytes:b'\xe9\xba\x83'
# id(63):255763 -->piece:鼷 bytes:b'\xe9\xbc\xb7'
# id(64):255764 -->piece:龱 bytes:b'\xe9\xbe\xb1'
# id(65):255765 -->piece:갛 bytes:b'\xea\xb0\x9b'
# id(66):255766 -->piece:뚠 bytes:b'\xeb\x9a\xa0'
# id(67):255767 -->piece:몭 bytes:b'\xeb\xaa\xad'
# id(68):255768 -->piece:뻥 bytes:b'\xeb\xbb\xa5'
# id(69):255769 -->piece:뿅 bytes:b'\xeb\xbf\x85'
# id(70):255770 -->piece:썽 bytes:b'\xec\x8d\xbd'
# id(71):255771 -->piece:옅 bytes:b'\xec\x98\x85'
# id(72):255772 -->piece:읭 bytes:b'\xec\x9d\xad'
# id(73):255773 -->piece:졍 bytes:b'\xec\xa1\x8d'
# id(74):255774 -->piece:좡 bytes:b'\xec\xa2\xa1'
# id(75):255775 -->piece:켭 bytes:b'\xec\xbc\xad'
# id(76):255776 -->piece:펍 bytes:b'\xed\x8e\x8d'
# id(77):255777 -->piece:횽 bytes:b'\xed\x9a\xbd'
# id(78):255778 -->piece: bytes:b'\xee\x80\xab'
# id(79):255779 -->piece: bytes:b'\xee\x80\xb9'
# id(80):255780 -->piece: bytes:b'\xee\x81\x99'
# id(81):255781 -->piece: bytes:b'\xee\x82\x82'
# id(82):255782 -->piece: bytes:b'\xee\x82\x8a'
# id(83):255783 -->piece: bytes:b'\xee\x83\xb1'
# id(84):255784 -->piece: bytes:b'\xee\x88\x9a'
# id(85):255785 -->piece: bytes:b'\xee\x8b\xa8'
# id(86):255786 -->piece: bytes:b'\xee\x8b\xb2'
# id(87):255787 -->piece: bytes:b'\xee\x8c\x94'
# id(88):255788 -->piece: bytes:b'\xee\x8d\xa8'
# id(89):255789 -->piece: bytes:b'\xee\x97\x92'
# id(90):255790 -->piece: bytes:b'\xee\x9c\xb4'
# id(91):255791 -->piece: bytes:b'\xee\x9c\xbe'
# id(92):255792 -->piece: bytes:b'\xee\x9d\xa2'
# id(93):255793 -->piece: bytes:b'\xee\x9d\xb7'
# id(94):255794 -->piece: bytes:b'\xee\xa1\x80'
# id(95):255795 -->piece: bytes:b'\xee\xb1\x8c'
# id(96):255796 -->piece: bytes:b'\xef\x84\x82'
# id(97):255797 -->piece: bytes:b'\xef\x85\xbd'
# id(98):255798 -->piece:兩 bytes:b'\xef\xa5\xb8'
# id(99):255799 -->piece:流 bytes:b'\xef\xa7\x8a'
# id(100):255800 -->piece:吏 bytes:b'\xef\xa7\x9e'
# id(101):255801 -->piece:ﭽ bytes:b'\xef\xad\xbd'
# id(102):255802 -->piece:︕ bytes:b'\xef\xb8\x95'
# id(103):255803 -->piece:﹛ bytes:b'\xef\xb9\x9b'
# id(104):255804 -->piece:ﺝ bytes:b'\xef\xba\x9d'
# id(105):255805 -->piece:𐌱 bytes:b'\xf0\x90\x8c\xb1'
# id(106):255806 -->piece:𑄠 bytes:b'\xf0\x91\x84\xa0'
# id(107):255807 -->piece:𝆣 bytes:b'\xf0\x9d\x86\xa3'
# id(108):255808 -->piece:𝑿 bytes:b'\xf0\x9d\x91\xbf'
# id(109):255809 -->piece:𝕲 bytes:b'\xf0\x9d\x95\xb2'
# id(110):255810 -->piece:𝘍 bytes:b'\xf0\x9d\x98\x8d'
# id(111):255811 -->piece:𝘒 bytes:b'\xf0\x9d\x98\x92'
# id(112):255812 -->piece:𝘜 bytes:b'\xf0\x9d\x98\x9c'
# id(113):255813 -->piece:𝝈 bytes:b'\xf0\x9d\x9d\x88'
# id(114):255814 -->piece:𞤑 bytes:b'\xf0\x9e\xa4\x91'
# id(115):255815 -->piece:🪕 bytes:b'\xf0\x9f\xaa\x95'
# id(116):255816 -->piece:🪤 bytes:b'\xf0\x9f\xaa\xa4'
# id(117):255817 -->piece:𨭆 bytes:b'\xf0\xa8\xad\x86'
# id(118):255818 -->piece: bytes:b'\x1c'
# id(119):255819 -->piece:ǈ bytes:b'\xc7\x88'
# id(120):255820 -->piece:ǋ bytes:b'\xc7\x8b'
# id(121):255821 -->piece:Ȟ bytes:b'\xc8\x9e'
# id(122):255822 -->piece:˕ bytes:b'\xcb\x95'
# id(123):255823 -->piece:ϛ bytes:b'\xcf\x9b'
# id(124):255824 -->piece:Ϡ bytes:b'\xcf\xa0'
# id(125):255825 -->piece:ѻ bytes:b'\xd1\xbb'
# id(126):255826 -->piece:Ӂ bytes:b'\xd3\x81'
# id(127):255827 -->piece:ӷ bytes:b'\xd3\xb7'
# id(128):255828 -->piece:֠ bytes:b'\xd6\xa0'
# id(129):255829 -->piece:ܴ bytes:b'\xdc\xb4'
# id(130):255830 -->piece:ߺ bytes:b'\xdf\xba'
# id(131):255831 -->piece:ऴ bytes:b'\xe0\xa4\xb4'
# id(132):255832 -->piece:ଃ bytes:b'\xe0\xac\x83'
# id(133):255833 -->piece:႐ bytes:b'\xe1\x82\x90'
# id(134):255834 -->piece:჻ bytes:b'\xe1\x83\xbb'
# id(135):255835 -->piece:ᄊ bytes:b'\xe1\x84\x8a'
# id(136):255836 -->piece:ᆹ bytes:b'\xe1\x86\xb9'
# id(137):255837 -->piece:ኾ bytes:b'\xe1\x8a\xbe'
# id(138):255838 -->piece:ዡ bytes:b'\xe1\x8b\xa1'
# id(139):255839 -->piece:ᒍ bytes:b'\xe1\x92\x8d'
# id(140):255840 -->piece:᠁ bytes:b'\xe1\xa0\x81'
# id(141):255841 -->piece:ḕ bytes:b'\xe1\xb8\x95'
# id(142):255842 -->piece:ṝ bytes:b'\xe1\xb9\x9d'
# id(143):255843 -->piece:ṽ bytes:b'\xe1\xb9\xbd'
# id(144):255844 -->piece:Ἤ bytes:b'\xe1\xbc\xac'
# id(145):255845 -->piece:ↆ bytes:b'\xe2\x86\x86'
# id(146):255846 -->piece:⇎ bytes:b'\xe2\x87\x8e'
# id(147):255847 -->piece:∭ bytes:b'\xe2\x88\xad'
# id(148):255848 -->piece:⊐ bytes:b'\xe2\x8a\x90'
# id(149):255849 -->piece:⏔ bytes:b'\xe2\x8f\x94'
# id(150):255850 -->piece:┥ bytes:b'\xe2\x94\xa5'
# id(151):255851 -->piece:⛛ bytes:b'\xe2\x9b\x9b'
# id(152):255852 -->piece:⠅ bytes:b'\xe2\xa0\x85'
# id(153):255853 -->piece:⠆ bytes:b'\xe2\xa0\x86'
# id(154):255854 -->piece:⠖ bytes:b'\xe2\xa0\x96'
# id(155):255855 -->piece:⡁ bytes:b'\xe2\xa1\x81'
# id(156):255856 -->piece:⡌ bytes:b'\xe2\xa1\x8c'
# id(157):255857 -->piece:⡑ bytes:b'\xe2\xa1\x91'
# id(158):255858 -->piece:⢊ bytes:b'\xe2\xa2\x8a'
# id(159):255859 -->piece:⢎ bytes:b'\xe2\xa2\x8e'
# id(160):255860 -->piece:⢐ bytes:b'\xe2\xa2\x90'
# id(161):255861 -->piece:⢫ bytes:b'\xe2\xa2\xab'
# id(162):255862 -->piece:⣜ bytes:b'\xe2\xa3\x9c'
# id(163):255863 -->piece:ⵌ bytes:b'\xe2\xb5\x8c'
# id(164):255864 -->piece:⽌ bytes:b'\xe2\xbd\x8c'
# id(165):255865 -->piece:⾄ bytes:b'\xe2\xbe\x84'
# id(166):255866 -->piece:⾳ bytes:b'\xe2\xbe\xb3'
# id(167):255867 -->piece:ㅙ bytes:b'\xe3\x85\x99'
# id(168):255868 -->piece:䴀 bytes:b'\xe4\xb4\x80'
# id(169):255869 -->piece:俁 bytes:b'\xe4\xbf\x81'
# id(170):255870 -->piece:俛 bytes:b'\xe4\xbf\x9b'
# id(171):255871 -->piece:倞 bytes:b'\xe5\x80\x9e'
# id(172):255872 -->piece:冋 bytes:b'\xe5\x86\x8b'
# id(173):255873 -->piece:凩 bytes:b'\xe5\x87\xa9'
# id(174):255874 -->piece:劒 bytes:b'\xe5\x8a\x92'
# id(175):255875 -->piece:勦 bytes:b'\xe5\x8b\xa6'
# id(176):255876 -->piece:喼 bytes:b'\xe5\x96\xbc'
# id(177):255877 -->piece:嗗 bytes:b'\xe5\x97\x97'
# id(178):255878 -->piece:垆 bytes:b'\xe5\x9e\x86'
# id(179):255879 -->piece:垪 bytes:b'\xe5\x9e\xaa'
# id(180):255880 -->piece:埝 bytes:b'\xe5\x9f\x9d'
# id(181):255881 -->piece:夲 bytes:b'\xe5\xa4\xb2'
# id(182):255882 -->piece:奷 bytes:b'\xe5\xa5\xb7'
# id(183):255883 -->piece:姸 bytes:b'\xe5\xa7\xb8'
# id(184):255884 -->piece:媖 bytes:b'\xe5\xaa\x96'
# id(185):255885 -->piece:寕 bytes:b'\xe5\xaf\x95'
# id(186):255886 -->piece:屨 bytes:b'\xe5\xb1\xa8'
# id(187):255887 -->piece:巂 bytes:b'\xe5\xb7\x82'
# id(188):255888 -->piece:怍 bytes:b'\xe6\x80\x8d'
# id(189):255889 -->piece:悒 bytes:b'\xe6\x82\x92'
# id(190):255890 -->piece:慤 bytes:b'\xe6\x85\xa4'
# id(191):255891 -->piece:搋 bytes:b'\xe6\x90\x8b'
# id(192):255892 -->piece:擽 bytes:b'\xe6\x93\xbd'
# id(193):255893 -->piece:昻 bytes:b'\xe6\x98\xbb'
# id(194):255894 -->piece:檠 bytes:b'\xe6\xaa\xa0'
# id(195):255895 -->piece:欵 bytes:b'\xe6\xac\xb5'
# id(196):255896 -->piece:殽 bytes:b'\xe6\xae\xbd'
# id(197):255897 -->piece:汌 bytes:b'\xe6\xb1\x8c'
# id(198):255898 -->piece:沇 bytes:b'\xe6\xb2\x87'
# id(199):255899 -->piece:涷 bytes:b'\xe6\xb6\xb7'
# id(200):255900 -->piece:淥 bytes:b'\xe6\xb7\xa5'
# id(201):255901 -->piece:滏 bytes:b'\xe6\xbb\x8f'
# id(202):255902 -->piece:濉 bytes:b'\xe6\xbf\x89'
# id(203):255903 -->piece:珖 bytes:b'\xe7\x8f\x96'
# id(204):255904 -->piece:瓛 bytes:b'\xe7\x93\x9b'
# id(205):255905 -->piece:甡 bytes:b'\xe7\x94\xa1'
# id(206):255906 -->piece:皝 bytes:b'\xe7\x9a\x9d'
# id(207):255907 -->piece:眛 bytes:b'\xe7\x9c\x9b'
# id(208):255908 -->piece:笅 bytes:b'\xe7\xac\x85'
# id(209):255909 -->piece:簣 bytes:b'\xe7\xb0\xa3'
# id(210):255910 -->piece:縒 bytes:b'\xe7\xb8\x92'
# id(211):255911 -->piece:臵 bytes:b'\xe8\x87\xb5'
# id(212):255912 -->piece:虓 bytes:b'\xe8\x99\x93'
# id(213):255913 -->piece:蚨 bytes:b'\xe8\x9a\xa8'
# id(214):255914 -->piece:蛧 bytes:b'\xe8\x9b\xa7'
# id(215):255915 -->piece:袮 bytes:b'\xe8\xa2\xae'
# id(216):255916 -->piece:裥 bytes:b'\xe8\xa3\xa5'
# id(217):255917 -->piece:谖 bytes:b'\xe8\xb0\x96'
# id(218):255918 -->piece:谞 bytes:b'\xe8\xb0\x9e'
# id(219):255919 -->piece:赑 bytes:b'\xe8\xb5\x91'
# id(220):255920 -->piece:趼 bytes:b'\xe8\xb6\xbc'
# id(221):255921 -->piece:醱 bytes:b'\xe9\x86\xb1'
# id(222):255922 -->piece:鉏 bytes:b'\xe9\x89\x8f'
# id(223):255923 -->piece:鉺 bytes:b'\xe9\x89\xba'
# id(224):255924 -->piece:韡 bytes:b'\xe9\x9f\xa1'
# id(225):255925 -->piece:頎 bytes:b'\xe9\xa0\x8e'
# id(226):255926 -->piece:飈 bytes:b'\xe9\xa3\x88'
# id(227):255927 -->piece:鯢 bytes:b'\xe9\xaf\xa2'
# id(228):255928 -->piece:鲆 bytes:b'\xe9\xb2\x86'
# id(229):255929 -->piece:鶿 bytes:b'\xe9\xb6\xbf'
# id(230):255930 -->piece:鹇 bytes:b'\xe9\xb9\x87'
# id(231):255931 -->piece:麁 bytes:b'\xe9\xba\x81'
# id(232):255932 -->piece:齙 bytes:b'\xe9\xbd\x99'
# id(233):255933 -->piece:龥 bytes:b'\xe9\xbe\xa5'
# id(234):255934 -->piece:ꘋ bytes:b'\xea\x98\x8b'
# id(235):255935 -->piece:걔 bytes:b'\xea\xb1\x94'
# id(236):255936 -->piece:먀 bytes:b'\xeb\xa8\x80'
# id(237):255937 -->piece:몄 bytes:b'\xeb\xaa\x84'
# id(238):255938 -->piece:삵 bytes:b'\xec\x82\xb5'
# id(239):255939 -->piece:쌩 bytes:b'\xec\x8c\xa9'
# id(240):255940 -->piece:읊 bytes:b'\xec\x9d\x8a'
# id(241):255941 -->piece:튿 bytes:b'\xed\x8a\xbf'
# id(242):255942 -->piece:횃 bytes:b'\xed\x9a\x83'
# id(243):255943 -->piece: bytes:b'\xee\x82\x8b'
# id(244):255944 -->piece: bytes:b'\xee\x82\xb9'
# id(245):255945 -->piece: bytes:b'\xee\x8a\x9a'
# id(246):255946 -->piece: bytes:b'\xee\x8a\xa2'
# id(247):255947 -->piece: bytes:b'\xee\x8b\x8a'
# id(248):255948 -->piece: bytes:b'\xee\x8b\x96'
# id(249):255949 -->piece: bytes:b'\xee\x8b\xa6'
# id(250):255950 -->piece: bytes:b'\xee\x8b\xb0'
# id(251):255951 -->piece: bytes:b'\xee\x90\x85'
# id(252):255952 -->piece: bytes:b'\xee\x98\x84'
# id(253):255953 -->piece: bytes:b'\xee\x99\x9a'
# id(254):255954 -->piece: bytes:b'\xee\x9a\x84'
# id(255):255955 -->piece: bytes:b'\xee\x9b\xac'

# %%
# %%
pieces_str = " ".join(pieces)
ic(pieces_str)
ic(sp.Encode(pieces_str)[:5])
ic(None)
# Out:
# ic| pieces_str: ('⢺ ⤙ ⾞ ㅚ 㠀 䊐 喈 噐 嚭 囷 堟 塤 夊 岽 巎 廔 彞 慥 扞 扺 攆 敉 榇 槩 殂 沺 炱 烀 琑 痦 盦 睃 籴 籺 粁 糹 紕 缐 '
#                  '缑 翆 臜 蒗 虯 蟶 袿 訫 謌 賔 踅 輅 轵 遄 釔 鋱 鍖 鏉 鏐 鏵 雱 驺 鴴 鷙 麃 鼷 龱 갛 뚠 몭 뻥 뿅 썽 옅 읭 졍 좡 켭 '
#                  '펍 횽 \ue02b \ue039 \ue059 \ue082 \ue08a \ue0f1 \ue21a \ue2e8 \ue2f2 \ue314 '
#                  '\ue368 \ue5d2 \ue734 \ue73e \ue762 \ue777 \ue840 \uec4c \uf102 \uf17d 兩 流 吏 '
#                  'ﭽ ︕ ﹛ ﺝ 𐌱 𑄠 𝆣 𝑿 𝕲 𝘍 𝘒 𝘜 𝝈 𞤑 🪕 🪤 𨭆 \x1c'
#                  ' ǈ ǋ Ȟ ˕ ϛ Ϡ ѻ Ӂ ӷ ֠ ܴ ߺ ऴ ଃ ႐ ჻ ᄊ ᆹ ኾ ዡ ᒍ ᠁ ḕ ṝ ṽ Ἤ ↆ ⇎ ∭ ⊐ ⏔ ┥ ⛛ ⠅ ⠆ ⠖ ⡁ ⡌ '
#                  '⡑ ⢊ ⢎ ⢐ ⢫ ⣜ ⵌ ⽌ ⾄ ⾳ ㅙ 䴀 俁 俛 倞 冋 凩 劒 勦 喼 嗗 垆 垪 埝 夲 奷 姸 媖 寕 屨 巂 怍 悒 慤 搋 擽 昻 檠 '
#                  '欵 殽 汌 沇 涷 淥 滏 濉 珖 瓛 甡 皝 眛 笅 簣 縒 臵 虓 蚨 蛧 袮 裥 谖 谞 赑 趼 醱 鉏 鉺 韡 頎 飈 鯢 鲆 鶿 鹇 麁 齙 '
#                  '龥 ꘋ 걔 먀 몄 삵 쌩 읊 튿 횃 \ue08b \ue0b9 \ue29a \ue2a2 \ue2ca \ue2d6 \ue2e6 \ue2f0 '
#                  '\ue405 \ue604 \ue65a \ue684 \ue6ec')
# ic| sp.Encode(pieces_str)[:5]: [255700, 235248, 255701, 235248, 255702]
# ic| None

# %%
# print(pieces_str)

ic(len(pieces_str))
ic(pieces_str.encode())

# %% [markdown]
# # Action Value → Token
#
# ```text
# Q: What should the robot do to <action>?
# A:“terminate pos pos pos rot rot rot gripper_extension”
# ```
# ## Steps
# - **step 1**: convert floating action values to discrete values(0~255)
# - **step 2**: convert discrete values to tokens

# %%
import numpy as np

np.clip(0.4, -0.3, 0.3)
# Out:
# 0.3

# %%
START_ID = 0
MAX_STEP_RANGE = 60  # mm (-30 ~ + 30)


def trans_val_to_id(action_val):
    action_val = np.clip(action_val, -0.03, 0.03)
    return int((action_val * 1000.0 + MAX_STEP_RANGE / 2) * 255 / 60 + 0.5) + START_ID


ic(trans_val_to_id(0))
ic(trans_val_to_id(0.030))
ic(trans_val_to_id(-0.030))
None
# Out:
# ic| action_val_to_id(0): 128
# ic| action_val_to_id(0.030): 255
# ic| action_val_to_id(-0.030): 0

# %%
def action_id_to_trans_val(action_id):
    action_id = np.clip(action_id, 0, 255)
    return (action_id - 128) * MAX_STEP_RANGE / 255 / 1000.0


ic(action_id_to_trans_val(128))
ic(action_id_to_trans_val(256))
ic(action_id_to_trans_val(0))
# Out:
# ic| action_id_to_action_val(128): 0.0
# ic| action_id_to_action_val(256): 0.02988235294117647
# ic| action_id_to_action_val(0): -0.03011764705882353
# -0.03011764705882353

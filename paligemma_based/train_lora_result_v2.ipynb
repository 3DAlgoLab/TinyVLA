# %%
from train_lora import train_lora
from util import prepare_test_dataset
# Out:
# 2024-07-04 09:43:23.331762: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-07-04 09:43:25.342815: W tensorflow/core/common_runtime/gpu/gpu_device.cc:2251] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...

# %%
from train_lora import PaliGemmaConfig

config = PaliGemmaConfig()
train_ds, val_ds = prepare_test_dataset()
train_lora(config, "./checkpoints", train_ds, val_ds)
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# Downloading the checkpoint from Kaggle, this could take a few minutes....
# Warning: Looks like you're using an outdated `kagglehub` version, please consider updating (latest version: 0.2.7)
# Model path: /home/j2y/.cache/kagglehub/models/google/paligemma/jax/paligemma-3b-pt-224/1/paligemma-3b-pt-224.f16.npz
# Successfully loaded and sharded model parameters!
# Train step size: 2434
# Model predictions before training...
# <div style="display: inline-flex; align-items: center; justify-content: center;">
#     <img style="width:128px; height:128px;" src="data:image/jpeg;base64,..." />
#     <p style="width:256px; margin:10px; font-size:small;">&lt;loc0046&gt;&lt;loc0233&gt;&lt;loc0896&gt;&lt;loc0921&gt; 1 ; &lt;loc0046&gt;&lt;loc0233&gt;&lt;loc0896&gt;&lt;loc0921&gt; 3 ; &lt;loc0046&gt;&lt;loc0505&gt;&lt;loc0896&gt;&lt;loc0696&gt; 7 ; &lt;loc0046&gt;&lt;loc0603&gt;&lt;loc0432&gt;&lt;loc0687&gt; 5 ; &lt;loc0046&gt;&lt;loc0233&gt;&lt;loc0536&gt;&lt;loc0912&gt; 6 ; &lt;loc0046&gt;&lt;loc0233&gt;&lt;loc0896&gt;&lt;loc0921&gt; 4 ; &lt;loc0046&gt;&lt;loc0233&gt;&lt;loc0533&gt;&lt;loc0912&gt; 9 ; &lt;loc0046&gt;&lt;loc0233&gt;&lt;loc0896&gt;&lt;loc0912&gt; 2 ; &lt;loc0046&gt;&lt;loc0233&gt;&lt;loc0531&gt;&lt;loc0912&gt; 8 ; &lt;loc0045&gt;&lt;loc0233&gt;&lt;loc0896&gt;&lt;loc0912&gt; 1 ; &lt;loc0045&gt;&lt;loc0000&gt;&lt;loc1023&gt;&lt;loc1013&gt; mult ; &lt;loc0045&gt;&lt;loc0541&gt;&lt;loc0896&gt;&lt;loc0690&gt; 7 ; &lt;loc0045&gt;&lt;loc0567&gt;&lt;loc0456&gt;&lt;loc0690&gt; minus ; &lt;loc0413&gt;&lt;loc0233&gt;&lt;loc0538&gt;&lt;loc0912&gt; div ; &lt;loc0036&gt;&lt;loc0000&gt;&lt;loc1023&gt;&lt;loc1015&gt; 1 ; &lt;loc0036&gt;&lt;loc0000&gt;&lt;loc1023&gt;&lt;loc1023&gt; 1 ; &lt;loc0036&gt;&lt;loc0000&gt;&lt;loc1023&gt;</p>
# </div>
#
# <div style="display: inline-flex; align-items: center; justify-content: center;">
#     <img style="width:128px; height:128px;" src="data:image/jpeg;base64,..." />
#     <p style="width:256px; margin:10px; font-size:small;">&lt;loc0217&gt;&lt;loc0261&gt;&lt;loc0957&gt;&lt;loc0819&gt; 4 ; &lt;loc0207&gt;&lt;loc0252&gt;&lt;loc0954&gt;&lt;loc0826&gt; 7 ; &lt;loc0207&gt;&lt;loc0246&gt;&lt;loc0949&gt;&lt;loc0826&gt; 5 ; &lt;loc0207&gt;&lt;loc0246&gt;&lt;loc0949&gt;&lt;loc0826&gt; 1 ; &lt;loc0207&gt;&lt;loc0421&gt;&lt;loc0778&gt;&lt;loc0703&gt; minus ; &lt;loc0000&gt;&lt;loc0000&gt;&lt;loc1023&gt;&lt;loc1017&gt; mult ; &lt;loc0207&gt;&lt;loc0246&gt;&lt;loc0949&gt;&lt;loc0818&gt; 3 ; &lt;loc0207&gt;&lt;loc0246&gt;&lt;loc0944&gt;&lt;loc0809&gt; 6 ; &lt;loc0754&gt;&lt;loc0264&gt;&lt;loc0936&gt;&lt;loc0513&gt; 8 ; &lt;loc0754&gt;&lt;loc0261&gt;&lt;loc0944&gt;&lt;loc0813&gt; 4 ; &lt;loc0754&gt;&lt;loc0261&gt;&lt;loc0936&gt;&lt;loc0513&gt; 5 ; &lt;loc0754&gt;&lt;loc0261&gt;&lt;loc0944&gt;&lt;loc0813&gt; 7 ; &lt;loc0754&gt;&lt;loc0261&gt;&lt;loc0936&gt;&lt;loc0813&gt; 9 ; &lt;loc0747&gt;&lt;loc0496&gt;&lt;loc0956&gt;&lt;loc0817&gt; div ; &lt;loc0000&gt;&lt;loc0000&gt;&lt;loc1023&gt;&lt;loc1017&gt; 1 ; &lt;loc0000&gt;&lt;loc0000&gt;&lt;loc1023&gt;&lt;loc1023&gt; 2 ; &lt;loc0000&gt;&lt;loc0000&gt;&lt;loc1023&gt;</p>
# </div>
#
# <div style="display: inline-flex; align-items: center; justify-content: center;">
#     <img style="width:128px; height:128px;" src="data:image/jpeg;base64,..." />
#     <p style="width:256px; margin:10px; font-size:small;">&lt;loc0116&gt;&lt;loc0230&gt;&lt;loc0920&gt;&lt;loc0634&gt; 1 ; &lt;loc0116&gt;&lt;loc0230&gt;&lt;loc0531&gt;&lt;loc0547&gt; 7 ; &lt;loc0116&gt;&lt;loc0230&gt;&lt;loc0920&gt;&lt;loc0629&gt; 3 ; &lt;loc0116&gt;&lt;loc0230&gt;&lt;loc0531&gt;&lt;loc0431&gt; 6 ; &lt;loc0116&gt;&lt;loc0222&gt;&lt;loc0925&gt;&lt;loc0629&gt; 4 ; &lt;loc0116&gt;&lt;loc0222&gt;&lt;loc0925&gt;&lt;loc0629&gt; 5 ; &lt;loc0116&gt;&lt;loc0222&gt;&lt;loc0541&gt;&lt;loc0553&gt; 8 ; &lt;loc0000&gt;&lt;loc0000&gt;&lt;loc1018&gt;&lt;loc1018&gt; mult ; &lt;loc0116&gt;&lt;loc0222&gt;&lt;loc0925&gt;&lt;loc0629&gt; 2 ; &lt;loc0116&gt;&lt;loc0230&gt;&lt;loc0541&gt;&lt;loc0557&gt; minus ; &lt;loc0866&gt;&lt;loc0404&gt;&lt;loc0922&gt;&lt;loc0658&gt; plus ; &lt;loc0168&gt;&lt;loc0505&gt;&lt;loc0906&gt;&lt;loc0580&gt; 4 ; &lt;loc0168&gt;&lt;loc0505&gt;&lt;loc0896&gt;&lt;loc0575&gt; 9 ; &lt;loc0866&gt;&lt;loc0403&gt;&lt;loc0922&gt;&lt;loc0658&gt; div ; &lt;loc0116&gt;&lt;loc0230&gt;&lt;loc0925&gt;&lt;loc0635&gt; 1 ; &lt;loc0116&gt;&lt;loc0230&gt;&lt;loc0925&gt;&lt;loc0626&gt; 7 ; &lt;loc0000&gt;&lt;loc0000&gt;&lt;loc1023&gt;&lt;loc1018&gt;</p>
# </div>
#
# <div style="display: inline-flex; align-items: center; justify-content: center;">
#     <img style="width:128px; height:128px;" src="data:image/jpeg;base64,..." />
#     <p style="width:256px; margin:10px; font-size:small;">&lt;loc0143&gt;&lt;loc0374&gt;&lt;loc0658&gt;&lt;loc0442&gt; 4 ; &lt;loc0143&gt;&lt;loc0374&gt;&lt;loc0658&gt;&lt;loc0441&gt; 5 ; &lt;loc0140&gt;&lt;loc0366&gt;&lt;loc0667&gt;&lt;loc0442&gt; 6 ; &lt;loc0000&gt;&lt;loc0000&gt;&lt;loc1023&gt;&lt;loc1017&gt; mult ; &lt;loc0140&gt;&lt;loc0366&gt;&lt;loc0667&gt;&lt;loc0442&gt; 7 ; &lt;loc0134&gt;&lt;loc0365&gt;&lt;loc0667&gt;&lt;loc0442&gt; 8 ; &lt;loc0000&gt;&lt;loc0000&gt;&lt;loc1023&gt;&lt;loc1017&gt; 3 ; &lt;loc0000&gt;&lt;loc0000&gt;&lt;loc1023&gt;&lt;loc1023&gt; 1 ; &lt;loc0000&gt;&lt;loc0000&gt;&lt;loc1023&gt;&lt;loc1023&gt; eq ; &lt;loc0000&gt;&lt;loc0000&gt;&lt;loc1023&gt;&lt;loc1023&gt; 2 ; &lt;loc0000&gt;&lt;loc0000&gt;&lt;loc0693&gt;&lt;loc1023&gt; 4 ; &lt;loc0000&gt;&lt;loc0000&gt;&lt;loc1023&gt;&lt;loc1023&gt; 9 ; &lt;loc0000&gt;&lt;loc0000&gt;&lt;loc1023&gt;&lt;loc1023&gt; minus ; &lt;loc0000&gt;&lt;loc0000&gt;&lt;loc1023&gt;&lt;loc1023&gt; 10 ; &lt;loc0000&gt;&lt;loc0356&gt;&lt;loc1023&gt;&lt;loc1023&gt; 3 ; &lt;loc0000&gt;&lt;loc0000&gt;&lt;loc1023&gt;&lt;loc1023&gt; 10 ; &lt;loc0000&gt;</p>
# </div>
# Training started...!
# Epoch:01 steps:001 loss:5.169
# Epoch:01 steps:002 loss:6.231
# Epoch:01 steps:003 loss:5.540
# Epoch:01 steps:004 loss:5.376
# Epoch:01 steps:005 loss:5.286
# Epoch:01 steps:006 loss:6.298
# Epoch:01 steps:007 loss:5.609
# Epoch:01 steps:008 loss:6.197
# Epoch:01 steps:009 loss:5.491
# Epoch:01 steps:010 loss:5.025
# Model predictions at epoch:1 step:10
# 2024-07-04 09:51:05.885411: W external/xla/xla/service/hlo_rematerialization.cc:2948] Can't reduce memory use below 2.26GiB (2431876272 bytes) by rematerialization; only reduced to 3.31GiB (3550027504 bytes), down from 3.31GiB (3550027504 bytes) originally
# 2024-07-04 09:51:21.390065: W external/tsl/tsl/framework/bfc_allocator.cc:482] Allocator (GPU_0_bfc) ran out of memory trying to allocate 2.96GiB (rounded to 3176030464)requested by op
# 2024-07-04 09:51:21.390392: W external/tsl/tsl/framework/bfc_allocator.cc:494] **************************************************************************__________________________
# 2024-07-04 09:51:21.390651: W external/tsl/tsl/framework/bfc_allocator.cc:482] Allocator (GPU_1_bfc) ran out of memory trying to allocate 2.96GiB (rounded to 3176030464)requested by op
# E0704 09:51:21.390750    7005 pjrt_stream_executor_client.cc:2826] Execution of replica 0 failed: RESOURCE_EXHAUSTED: Out of memory while trying to allocate 3176030352 bytes.
# BufferAssignment OOM Debugging.
# BufferAssignment stats:
#              parameter allocation:    3.23GiB
#               constant allocation:         8B
#         maybe_live_out allocation:   19.96MiB
#      preallocated temp allocation:    2.96GiB
#   preallocated temp fragmentation:       112B (0.00%)
#                  total allocation:    6.21GiB
#               total fragmentation:   10.97MiB (0.17%)
# Peak buffers:
# 	Buffer 1:
# 		Size: 1.96GiB
# 		Operator: op_name="jit(_prefill_cache)/jit(main)/Model.prefill_cache/llm.prefill_cache/llm.compute_logits/Model/embedder.decode/dot_general[dimension_numbers=(((2,), (0,)), ((), ())) precision=None preferred_element_type=float32]" source_file="/dev_repo/TinyVLA/packages/big_vision/big_vision/models/ppp/gemma.py" source_line=175
# 		XLA Label: all-gather-start
# 		Shape: f32[2048,257152]
# 		==========================
#
# 	Buffer 2:
# 		Size: 1.12GiB
# 		Entry Parameter Subshape: f16[18,2,2048,8192]
# 		==========================
#
# 	Buffer 3:
# 		Size: 1004.50MiB
# 		Operator: op_name="jit(_prefill_cache)/jit(main)/Model.prefill_cache/llm.prefill_cache/llm.compute_logits/Model/embedder.decode/dot_general[dimension_numbers=(((2,), (0,)), ((), ())) precision=None preferred_element_type=float32]" source_file="/dev_repo/TinyVLA/packages/big_vision/big_vision/models/ppp/gemma.py" source_line=175
# 		XLA Label: fusion
# 		Shape: f32[128576,2048]
# 		==========================
#
# 	Buffer 4:
# 		Size: 576.00MiB
# 		Entry Parameter Subshape: f16[9,16384,2048]
# 		==========================
#
# 	Buffer 5:
# 		Size: 502.25MiB
# 		Operator: op_name="jit(_prefill_cache)/jit(main)/Model.prefill_cache/llm.prefill_cache/llm.compute_logits/Model/embedder.decode/transpose[permutation=(1, 0)]" source_file="/dev_repo/TinyVLA/packages/big_vision/big_vision/models/ppp/gemma.py" source_line=175
# 		Entry Parameter Subshape: f16[128576,2048]
# 		==========================
#
# 	Buffer 6:
# 		Size: 255.34MiB
# 		Entry Parameter Subshape: f16[27,4304,1152]
# 		==========================
#
# 	Buffer 7:
# 		Size: 255.34MiB
# 		Entry Parameter Subshape: f16[27,1152,4304]
# 		==========================
#
# 	Buffer 8:
# 		Size: 144.00MiB
# 		Entry Parameter Subshape: f32[9,8,2048,256]
# 		==========================
#
# 	Buffer 9:
# 		Size: 72.00MiB
# 		Entry Parameter Subshape: f32[18,2,1,2048,256]
# 		==========================
#
# 	Buffer 10:
# 		Size: 72.00MiB
# 		Entry Parameter Subshape: f16[9,8,256,2048]
# 		==========================
#
# 	Buffer 11:
# 		Size: 68.34MiB
# 		Entry Parameter Subshape: f16[27,1152,16,72]
# 		==========================
#
# 	Buffer 12:
# 		Size: 68.34MiB
# 		Entry Parameter Subshape: f16[27,1152,16,72]
# 		==========================
#
# 	Buffer 13:
# 		Size: 68.34MiB
# 		Entry Parameter Subshape: f16[27,16,72,1152]
# 		==========================
#
# 	Buffer 14:
# 		Size: 68.34MiB
# 		Entry Parameter Subshape: f16[27,1152,16,72]
# 		==========================
#
# 	Buffer 15:
# 		Size: 9.00MiB
# 		Operator: op_name="jit(_prefill_cache)/jit(main)/Model.prefill_cache/llm.prefill_cache/Model/while[cond_nconsts=0 body_nconsts=9]" source_file="/home/j2y/envs/vla/lib/python3.11/site-packages/flax/core/axes_scan.py" source_line=165 deduplicated_name="loop_transpose_fusion.3"
# 		XLA Label: fusion
# 		Shape: bf16[2,18,512,1,256]
# 		==========================
#
#
# 2024-07-04 09:51:21.390913: W external/tsl/tsl/framework/bfc_allocator.cc:494] **************************************************************************__________________________
# E0704 09:51:21.391122    7007 pjrt_stream_executor_client.cc:2826] Execution of replica 0 failed: RESOURCE_EXHAUSTED: Out of memory while trying to allocate 3176030352 bytes.
# BufferAssignment OOM Debugging.
# BufferAssignment stats:
#              parameter allocation:    3.23GiB
#               constant allocation:         8B
#         maybe_live_out allocation:   19.96MiB
#      preallocated temp allocation:    2.96GiB
#   preallocated temp fragmentation:       112B (0.00%)
#                  total allocation:    6.21GiB
#               total fragmentation:   10.97MiB (0.17%)
# Peak buffers:
# 	Buffer 1:
# 		Size: 1.96GiB
# 		Operator: op_name="jit(_prefill_cache)/jit(main)/Model.prefill_cache/llm.prefill_cache/llm.compute_logits/Model/embedder.decode/dot_general[dimension_numbers=(((2,), (0,)), ((), ())) precision=None preferred_element_type=float32]" source_file="/dev_repo/TinyVLA/packages/big_vision/big_vision/models/ppp/gemma.py" source_line=175
# 		XLA Label: all-gather-start
# 		Shape: f32[2048,257152]
# 		==========================
#
# 	Buffer 2:
# 		Size: 1.12GiB
# 		Entry Parameter Subshape: f16[18,2,2048,8192]
# 		==========================
#
# 	Buffer 3:
# 		Size: 1004.50MiB
# 		Operator: op_name="jit(_prefill_cache)/jit(main)/Model.prefill_cache/llm.prefill_cache/llm.compute_logits/Model/embedder.decode/dot_general[dimension_numbers=(((2,), (0,)), ((), ())) precision=None preferred_element_type=float32]" source_file="/dev_repo/TinyVLA/packages/big_vision/big_vision/models/ppp/gemma.py" source_line=175
# 		XLA Label: fusion
# 		Shape: f32[128576,2048]
# 		==========================
#
# 	Buffer 4:
# 		Size: 576.00MiB
# 		Entry Parameter Subshape: f16[9,16384,2048]
# 		==========================
#
# 	Buffer 5:
# 		Size: 502.25MiB
# 		Operator: op_name="jit(_prefill_cache)/jit(main)/Model.prefill_cache/llm.prefill_cache/llm.compute_logits/Model/embedder.decode/transpose[permutation=(1, 0)]" source_file="/dev_repo/TinyVLA/packages/big_vision/big_vision/models/ppp/gemma.py" source_line=175
# 		Entry Parameter Subshape: f16[128576,2048]
# 		==========================
#
# 	Buffer 6:
# 		Size: 255.34MiB
# 		Entry Parameter Subshape: f16[27,4304,1152]
# 		==========================
#
# 	Buffer 7:
# 		Size: 255.34MiB
# 		Entry Parameter Subshape: f16[27,1152,4304]
# 		==========================
#
# 	Buffer 8:
# 		Size: 144.00MiB
# 		Entry Parameter Subshape: f32[9,8,2048,256]
# 		==========================
#
# 	Buffer 9:
# 		Size: 72.00MiB
# 		Entry Parameter Subshape: f32[18,2,1,2048,256]
# 		==========================
#
# 	Buffer 10:
# 		Size: 72.00MiB
# 		Entry Parameter Subshape: f16[9,8,256,2048]
# 		==========================
#
# 	Buffer 11:
# 		Size: 68.34MiB
# 		Entry Parameter Subshape: f16[27,1152,16,72]
# 		==========================
#
# 	Buffer 12:
# 		Size: 68.34MiB
# 		Entry Parameter Subshape: f16[27,1152,16,72]
# 		==========================
#
# 	Buffer 13:
# 		Size: 68.34MiB
# 		Entry Parameter Subshape: f16[27,16,72,1152]
# 		==========================
#
# 	Buffer 14:
# 		Size: 68.34MiB
# 		Entry Parameter Subshape: f16[27,1152,16,72]
# 		==========================
#
# 	Buffer 15:
# 		Size: 9.00MiB
# 		Operator: op_name="jit(_prefill_cache)/jit(main)/Model.prefill_cache/llm.prefill_cache/Model/while[cond_nconsts=0 body_nconsts=9]" source_file="/home/j2y/envs/vla/lib/python3.11/site-packages/flax/core/axes_scan.py" source_line=165 deduplicated_name="loop_transpose_fusion.3"
# 		XLA Label: fusion
# 		Shape: bf16[2,18,512,1,256]
# 		==========================
# ---------------------------------------------------------------------------
# XlaRuntimeError                           Traceback (most recent call last)
# Cell In[2], line 5
#       3 config = PaliGemmaConfig()
#       4 train_ds, val_ds = prepare_test_dataset()
# ----> 5 train_lora(config, "./checkpoints", train_ds, val_ds)
#
# File /dev_repo/TinyVLA/paligemma_based/train_lora.py:663, in train_lora(config, checkpoint_dir, train_dataset, val_dataset, verbose, checkpoint_prefix)
#     661 html_out = ""
#     662 params_merged = merge_lora_params(params, lora_map)
# --> 663 for image, _, caption in make_predictions(
#     664     val_data_iter,
#     665     decode,
#     666     params_merged,
#     667     tokenizer,
#     668     data_sharding=data_sharding,
#     669     num_examples=4,
#     670     batch_size=4,
#     671 ):
#     672     html_out += util.render_example(
#     673         image, caption, classes=NUM_DETECTION_CLASSES
#     674     )
#     675 util.display(util.HTML(html_out))
#
# File /dev_repo/TinyVLA/paligemma_based/train_lora.py:725, in make_predictions(data_iterator, decode, params, tokenizer, data_sharding, num_examples, batch_size, seqlen, sampler)
#     722 batch = big_vision.utils.reshard(batch, data_sharding)
#     724 # Make model predictions
# --> 725 tokens = decode(
#     726     {"params": params}, batch=batch, max_decode_len=seqlen, sampler=sampler
#     727 )
#     729 # Fetch model predictions to device and detokenize.
#     730 tokens, mask = jax.device_get((tokens, batch["_mask"]))
#
# File /dev_repo/TinyVLA/packages/big_vision/big_vision/trainers/proj/paligemma/predict_fns.py:122, in _decode(train_state, batch, **kwargs)
#     121 def _decode(train_state, batch, **kwargs):
# --> 122   tokens, _ = _decode_with_logp(train_state, batch, **kwargs)
#     123   return tokens
#
# File /dev_repo/TinyVLA/packages/big_vision/big_vision/trainers/proj/paligemma/predict_fns.py:84, in _decode_with_logp(train_state, batch, model, devices, max_decode_len, eos_token, best_of_n, sampler)
#      79   return lambda *a, **kw: jax.jit(
#      80       fn, **jit_kw, out_shardings=out_shardings, static_argnames=kw.keys()
#      81   )(*a, **kw)
#      83 # Prefill the model cache and generate logits for first token.
# ---> 84 logits, cache = jit(_prefill_cache)(
#      85     train_state["params"], {
#      86         "image": batch["image"],
#      87         "text": batch["text"],
#      88         "mask_input": batch["mask_input"],
#      89         "mask_ar": batch["mask_ar"],
#      90     },
#      91     model=model, max_decode_len=max_decode_len)
#      93 # Mask indicating real examples. False if example is used to pad the batch.
#      94 mask = batch["_mask"]
#
# File /dev_repo/TinyVLA/packages/big_vision/big_vision/trainers/proj/paligemma/predict_fns.py:79, in _decode_with_logp.<locals>.jit.<locals>.<lambda>(*a, **kw)
#      78 def jit(fn, *, out_shardings=data_sharding, **jit_kw):
# ---> 79   return lambda *a, **kw: jax.jit(
#      80       fn, **jit_kw, out_shardings=out_shardings, static_argnames=kw.keys()
#      81   )(*a, **kw)
#
#     [... skipping hidden 10 frame]
#
# File ~/envs/vla/lib/python3.11/site-packages/jax/_src/interpreters/pxla.py:1185, in ExecuteReplicated.__call__(self, *args)
#    1183   self._handle_token_bufs(result_token_bufs, sharded_runtime_token)
#    1184 else:
# -> 1185   results = self.xla_executable.execute_sharded(input_bufs)
#    1186 if dispatch.needs_check_special():
#    1187   out_arrays = results.disassemble_into_single_device_arrays()
#
# XlaRuntimeError: RESOURCE_EXHAUSTED: Out of memory while trying to allocate 3176030352 bytes.
# BufferAssignment OOM Debugging.
# BufferAssignment stats:
#              parameter allocation:    3.23GiB
#               constant allocation:         8B
#         maybe_live_out allocation:   19.96MiB
#      preallocated temp allocation:    2.96GiB
#   preallocated temp fragmentation:       112B (0.00%)
#                  total allocation:    6.21GiB
#               total fragmentation:   10.97MiB (0.17%)
# Peak buffers:
# 	Buffer 1:
# 		Size: 1.96GiB
# 		Operator: op_name="jit(_prefill_cache)/jit(main)/Model.prefill_cache/llm.prefill_cache/llm.compute_logits/Model/embedder.decode/dot_general[dimension_numbers=(((2,), (0,)), ((), ())) precision=None preferred_element_type=float32]" source_file="/dev_repo/TinyVLA/packages/big_vision/big_vision/models/ppp/gemma.py" source_line=175
# 		XLA Label: all-gather-start
# 		Shape: f32[2048,257152]
# 		==========================
#
# 	Buffer 2:
# 		Size: 1.12GiB
# 		Entry Parameter Subshape: f16[18,2,2048,8192]
# 		==========================
#
# 	Buffer 3:
# 		Size: 1004.50MiB
# 		Operator: op_name="jit(_prefill_cache)/jit(main)/Model.prefill_cache/llm.prefill_cache/llm.compute_logits/Model/embedder.decode/dot_general[dimension_numbers=(((2,), (0,)), ((), ())) precision=None preferred_element_type=float32]" source_file="/dev_repo/TinyVLA/packages/big_vision/big_vision/models/ppp/gemma.py" source_line=175
# 		XLA Label: fusion
# 		Shape: f32[128576,2048]
# 		==========================
#
# 	Buffer 4:
# 		Size: 576.00MiB
# 		Entry Parameter Subshape: f16[9,16384,2048]
# 		==========================
#
# 	Buffer 5:
# 		Size: 502.25MiB
# 		Operator: op_name="jit(_prefill_cache)/jit(main)/Model.prefill_cache/llm.prefill_cache/llm.compute_logits/Model/embedder.decode/transpose[permutation=(1, 0)]" source_file="/dev_repo/TinyVLA/packages/big_vision/big_vision/models/ppp/gemma.py" source_line=175
# 		Entry Parameter Subshape: f16[128576,2048]
# 		==========================
#
# 	Buffer 6:
# 		Size: 255.34MiB
# 		Entry Parameter Subshape: f16[27,4304,1152]
# 		==========================
#
# 	Buffer 7:
# 		Size: 255.34MiB
# 		Entry Parameter Subshape: f16[27,1152,4304]
# 		==========================
#
# 	Buffer 8:
# 		Size: 144.00MiB
# 		Entry Parameter Subshape: f32[9,8,2048,256]
# 		==========================
#
# 	Buffer 9:
# 		Size: 72.00MiB
# 		Entry Parameter Subshape: f32[18,2,1,2048,256]
# 		==========================
#
# 	Buffer 10:
# 		Size: 72.00MiB
# 		Entry Parameter Subshape: f16[9,8,256,2048]
# 		==========================
#
# 	Buffer 11:
# 		Size: 68.34MiB
# 		Entry Parameter Subshape: f16[27,1152,16,72]
# 		==========================
#
# 	Buffer 12:
# 		Size: 68.34MiB
# 		Entry Parameter Subshape: f16[27,1152,16,72]
# 		==========================
#
# 	Buffer 13:
# 		Size: 68.34MiB
# 		Entry Parameter Subshape: f16[27,16,72,1152]
# 		==========================
#
# 	Buffer 14:
# 		Size: 68.34MiB
# 		Entry Parameter Subshape: f16[27,1152,16,72]
# 		==========================
#
# 	Buffer 15:
# 		Size: 9.00MiB
# 		Operator: op_name="jit(_prefill_cache)/jit(main)/Model.prefill_cache/llm.prefill_cache/Model/while[cond_nconsts=0 body_nconsts=9]" source_file="/home/j2y/envs/vla/lib/python3.11/site-packages/flax/core/axes_scan.py" source_line=165 deduplicated_name="loop_transpose_fusion.3"
# 		XLA Label: fusion
# 		Shape: bf16[2,18,512,1,256]
# 		==========================
#
# : while running replica 0 and partition 0 of a replicated computation (other replicas may have failed as well).
